# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '98_Pandas.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas as pd

# %%
df1 = pd.read_csv('supermarkets.csv', index_col='ID')

# %%
df1
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.shape
# Out:
# (6, 6)

# %%
df2 = pd.read_json('supermarkets.json')

# %%
df2.set_index('ID')
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3 = pd.read_excel('supermarkets.xlsx',sheet_name=0, index_col='ID')

# %%
df3
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pd.read_csv('supermarkets-commas.txt', index_col='ID')

# %%
df4
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5 = pd.read_csv('supermarkets-semi-colons.txt', sep=';', index_col='ID')

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6 = pd.read_csv('http://pythonhow.com/supermarkets.csv')
df6.set_index('ID')
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = pd.read_json('http://pythonhow.com/supermarkets.json')
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.loc[3,'City':'Name']
# Out:
# City         San Francisco
# Country                USA
# Employees               10
# ID                       4
# Name            Ben's Shop
# Name: 3, dtype: object

# %%
df7.iloc[4,2]
# Out:
# 'USA'

# %%
df7.ix[0,5]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'Madeira'

# %%
df7_org=df7
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7 = df7.drop(df7.columns[0:3],1)
df7
# Out:
#    Employees  ID         Name             State
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114

# %%
df7.drop(df7.index[2:4],0,inplace=True)
df7
# Out:
#    Employees  ID         Name       State
# 0          8   1      Madeira    CA 94114
# 1         15   2  Bready Shop    CA 94119
# 4         12   5      Sanchez  California
# 5         20   6   Richvalley    CA 94114

# %%
df7.reindex([1,2,3,4])
# Out:
#    Employees   ID         Name       State
# 1       15.0  2.0  Bready Shop    CA 94119
# 2        NaN  NaN          NaN         NaN
# 3        NaN  NaN          NaN         NaN
# 4       12.0  5.0      Sanchez  California

# %%
df7.columns
# Out:
# Index(['Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df7['Continent'] = df7.shape[0]*['North America']

# %%
df7
# Out:
#    Employees  ID         Name       State      Continent
# 0          8   1      Madeira    CA 94114  North America
# 1         15   2  Bready Shop    CA 94119  North America
# 4         12   5      Sanchez  California  North America
# 5         20   6   Richvalley    CA 94114  North America

# %%
df7['Continent'] = df7['Name']+','+'North America'

# %%
df7
# Out:
#    Employees  ID         Name       State                  Continent
# 0          8   1      Madeira    CA 94114      Madeira,North America
# 1         15   2  Bready Shop    CA 94119  Bready Shop,North America
# 4         12   5      Sanchez  California      Sanchez,North America
# 5         20   6   Richvalley    CA 94114   Richvalley,North America

# %%
df7_t = df7.T

# %%
df7_t
# Out:
#                                0                          1  \
# Employees                      8                         15
# ID                             1                          2
# Name                     Madeira                Bready Shop
# State                   CA 94114                   CA 94119
# Continent  Madeira,North America  Bready Shop,North America
#
#                                4                         5
# Employees                     12                        20
# ID                             5                         6
# Name                     Sanchez                Richvalley
# State                 California                  CA 94114
# Continent  Sanchez,North America  Richvalley,North America

# %%
df7_t[6] = [6, '102', 'Rafal', 'Minsk', 'Europa']

# %%
df7_t.T
# Out:
#   Employees   ID         Name       State                  Continent
# 0         8    1      Madeira    CA 94114      Madeira,North America
# 1        15    2  Bready Shop    CA 94119  Bready Shop,North America
# 4        12    5      Sanchez  California      Sanchez,North America
# 5        20    6   Richvalley    CA 94114   Richvalley,North America
# 6         6  102        Rafal       Minsk                     Europa

# %%
df7_t.T.iloc[2,2] = 'Jacek'

# %%
df7_t.T
# Out:
#   Employees   ID         Name       State                  Continent
# 0         8    1      Madeira    CA 94114      Madeira,North America
# 1        15    2  Bready Shop    CA 94119  Bready Shop,North America
# 4        12    5        Jacek  California      Sanchez,North America
# 5        20    6   Richvalley    CA 94114   Richvalley,North America
# 6         6  102        Rafal       Minsk                     Europa

# %%
df7_org
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
import geopy

# %%
nom = ArcGIS()

# %%
n = nom.geocode('05-300 Mińsk Mazowiecki, Sienicka 57B, Poland')
n
# Out:
# Location(ulica Siennicka 57B, 05-300, Mińsk Mazowiecki, Powiat Miński, Woj. Mazowieckie, (52.16873954342441, 21.56915791173757, 0.0))

# %%
n.longitude
# Out:
# 21.56915791173757

# %%
n.latitude
# Out:
# 52.16873954342441

# %%
import pandas as pd
df = pd.read_csv('supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df['Full_adress'] = df.Address+ ',' +df.City+ ',' +df.State+ ',' +df.Country

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                     Full_adress
# 0          8         3666 21st St,San Francisco,CA 94114,USA
# 1         15       735 Dolores St,San Francisco,CA 94119,USA
# 2         25  332 Hill St,San Francisco,California 94114,USA
# 3         10         3995 23rd St,San Francisco,CA 94114,USA
# 4         12    1056 Sanchez St,San Francisco,California,USA
# 5         20      551 Alvarado St,San Francisco,CA 94114,USA

# %%
df['Coordinates'] = df['Full_adress'].apply(nom.geocode)

# %%
df.ix[:,-2:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                       Full_adress  \
# 0         3666 21st St,San Francisco,CA 94114,USA
# 1       735 Dolores St,San Francisco,CA 94119,USA
# 2  332 Hill St,San Francisco,California 94114,USA
# 3         3995 23rd St,San Francisco,CA 94114,USA
# 4    1056 Sanchez St,San Francisco,California,USA
# 5      551 Alvarado St,San Francisco,CA 94114,USA
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# 1  (735 Dolores St, San Francisco, California, 94...
# 2  (332 Hill St, San Francisco, California, 94114...
# ...

# %%
df.Coordinates[0].latitude
# Out:
# 37.75644449321933

# %%
df['Latitude']=df['Coordinates'].apply(lambda x: x.latitude if x != None else None)
df['Laongitude']=df['Coordinates'].apply(lambda x: x.longitude if x != None else None)

# %%
df.ix[:,-3:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                          Coordinates   Latitude  Laongitude
# 0  (3666 21st St, San Francisco, California, 9411...  37.756444 -122.429353
# 1  (735 Dolores St, San Francisco, California, 94...  37.757801 -122.425599
# 2  (332 Hill St, San Francisco, California, 94114...  37.755641 -122.428794
# 3  (3995 23rd St, San Francisco, California, 9411...  37.752985 -122.431702
# 4  (1056 Sanchez St, San Francisco, California, 9...  37.752144 -122.429758
# 5  (551 Alvarado St, San Francisco, California, 9...  37.753709 -122.433251
